# %%
import pandas as pd

# %%
df = pd.read_csv('tree_res.csv')

# %%
slice = df.iloc[230:235][['tree', 'activity_stream']]

# %%
import ast

for idx, (tree, activity_stream) in slice.iterrows():
    
    print(idx)
    print(tree)
    if str(activity_stream) != 'nan':
        [print(el) for el in ast.literal_eval(activity_stream)]
    print()
    print()
    print()
    print()
    print()
    print()
# Out:
# 230
# [o] Bot [✓]
#     {-} root (shipyard defence) [✕]
#         --> Incoming fleet [✕]
#         --> Enough fleet to defend [-]
#         [o] Build or use leftover fleet to mine [-]
#             {-} Fleet production [-]
#                 --> Need to build [-]
#                 --> Build fleet [-]
#             [o] root (gathering) [-]
#                 {-} Fleet number check [-]
#                     --> Not Enough Fleet [-]
#                     --> Build fleet [-]
#                 {-} Gathering [-]
#                     --> Get all routes of max length 7 [-]
#                     [o] Is_Route [-]
#                         {-} Launch Fleet [-]
#                             --> Is available routes (greedy)? [-]
#                             --> Launch  fleet (greedy) [-]
#                         --> Build fleet [-]
#     {-} root (fleet generation mirroring) [✓]
#         --> Closest ennemy is Amassing Fleet [✓]
#         --> Build fleet [✓]
#     {-} root (shipyard expand) [-]
# ...
